# %%
import script as sc

# %% [markdown]
# # <center> <font color = 'royalblue'> **Análise Exploratória dos Preços dos Combustíveis no Brasil** </font> </center>
#
# ## <center> <font color = 'seagreen'> **Introdução** </font> </center>
#
# Neste notebook, realizamos uma análise exploratória das séries históricas de preço de venda dos combustíveis no Brasil. O objetivo é investigar os comportamentos dos preços ao longo de um período específico, responder a perguntas-chave e apresentar insights significativos.
#
# ## <center> <font color = 'seagreen'> **Metodologia** </font> </center>
#
# ### Fontes de Dados
#
# Para realizar esta análise, utilizamos dados da Agência Nacional de Petróleo e Gás Natural e Biocombustíveis (ANP). Os arquivos dos dois últimos meses do ano atual foram obtidos a partir dos seguintes links:
#
# - [Dados Maio](https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-abertos/arquivos/shpc/dsan/2023/precos-gasolina-etanol-05.csv)
# - [Dados Junho](https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-abertos/arquivos/shpc/dsan/2023/precos-gasolina-etanol-06.csv)

# %% [markdown]
# ### Utilização de Bibliotecas na Análise de Dados
#
# No processo de desenvolvimento e aprimoramento da análise, adotamos uma abordagem que se baseia na utilização de diversas bibliotecas renomadas, visando a obtenção de insights significativos a partir dos dados coletados. A seguir, apresentamos as bibliotecas que foram importadas e como cada uma delas contribuiu para o processo de análise:
#
# 1. Pandas
#
# A biblioteca **pandas** desempenhou um papel fundamental ao permitir a manipulação eficiente dos dados em formato de tabelas. Através do uso de DataFrames, conseguimos carregar, explorar e transformar os dados, tornando a limpeza e preparação dos mesmos para análise uma tarefa mais acessível.
#
# 2. Matplotlib.pyplot e Seaborn
#
# Para a visualização dos dados, contamos com as bibliotecas **matplotlib.pyplot** e **seaborn**. Essas ferramentas nos possibilitaram criar gráficos e visualizações claras e informativas. Através de uma variedade de tipos de gráficos, fomos capazes de comunicar padrões e tendências presentes nos dados de maneira eficaz.
#
# 3. Numpy
#
# A biblioteca **numpy** se mostrou essencial para a realização de cálculos numéricos e operações matemáticas. Com suas funcionalidades, conseguimos realizar transformações nos dados e executar cálculos complexos de maneira otimizada.
#
# 4. Requests, Zipfile e Io
#
# O conjunto formado pelas bibliotecas **requests**, **zipfile** e **io** nos permitiu o acesso e a manipulação de arquivos remotos. Essa combinação foi empregada na obtenção e descompactação de arquivos de dados, facilitando a incorporação de novos conjuntos de dados à análise.
#
# 5. Geopandas e Matplotlib.colors
#
# A utilização das bibliotecas **geopandas** e **matplotlib.colors** nos possibilitou integrar dados geoespaciais à análise. Com essas ferramentas, conseguimos representar informações geográficas em mapas, enriquecendo a análise com aspectos espaciais.
#
# 6. Matplotlib.ticker
#
# A biblioteca **matplotlib.ticker** foi empregada para o refinamento dos detalhes dos gráficos, permitindo um controle mais preciso dos rótulos dos eixos e da formatação dos valores exibidos nos gráficos.
#
# 7. Unicodedata
#
# A biblioteca **unicodedata** desempenhou um papel importante na normalização de caracteres, contribuindo para a consistência e a integridade dos dados que envolvem informações textuais.
#
# A combinação dessas bibliotecas proporcionou uma abordagem robusta e eficaz para a análise de dados. Ao tirar proveito das funcionalidades específicas de cada uma, conseguimos explorar os dados de forma abrangente, identificar padrões relevantes e gerar insights que enriqueceram nosso entendimento do conjunto de dados em estudo.

# %% [markdown]
# ### Importação e Comparação de Preços de Combustíveis - Maio e Junho de 2023
#
# Para enriquecer nossa análise, incorporamos um conjunto de dados essencial fornecido pela Agência Nacional do Petróleo, Gás Natural e Biocombustíveis (ANP). Esses dados nos permitem comparar os preços de combustíveis, incluindo gasolina e etanol, durante os meses de maio e junho de 2023 em todo o Brasil.

# %% [markdown]
# ### Combinação dos Dados
# Utilizando a biblioteca pandas, fizemos a combinação dos dados de preços de combustíveis dos dois meses em um único DataFrame. Isso nos permitiu ter uma visão consolidada dos preços para ambos os meses e facilitou a análise comparativa.

# %% [markdown]
# ### Carregamento dos Dados e Mapeamento de Siglas
# Iniciamos por carregar os dados de preços de gasolina e etanol para ambos os meses. Além disso, utilizamos um dicionário de siglas para estados, que mapeia as siglas dos estados para seus nomes completos, a fim de facilitar a interpretação dos resultados.

# %% [markdown]
# ### Mapeamento de Siglas de Regiões
# Incorporamos um dicionário que mapeia as siglas das regiões do Brasil para seus nomes completos, aprimorando a legibilidade e interpretabilidade dos resultados. Isso nos permitiu identificar mais facilmente as variações de preços em cada região.

# %% [markdown]
# ### Conversão da Coluna 'Data da Coleta'
#
# Prosseguindo na análise da variação de preços de combustíveis durante os meses de maio e junho de 2023, efetuamos uma etapa adicional de preparação dos dados. Agora, convertemos a coluna 'Data da Coleta' para o tipo datetime e organizamos as datas no formato (YYYY/mm/dd) para facilitar a interpretação, tratar as datas de maneira mais eficiente e realizar análises temporais mais precisas.
# Além disso, organizamos as datas no formato (YYYY/mm/dd), o que facilita a interpretação e comparação das datas ao longo dos meses. Essa padronização visual contribui para uma análise mais clara e consistente.
#
# ### Ordenação do DataFrame por Data
#
# Realizamos a ordenação do DataFrame pela coluna 'Data da Coleta'. Essa ação nos permite visualizar a evolução dos preços médios de revenda de combustíveis de forma sequencial ao longo do tempo. Essa abordagem fornece uma análise temporal mais precisa e nos ajuda a identificar tendências ao longo de cada mês.

# %% [markdown]
# ### Análise da Variação por Dia da Semana
#
# Criamos uma nova coluna chamada 'Dia da Semana', mapeando os nomes dos dias da semana com base na coluna 'Data da Coleta', utilizando um dicionário específico. Isso nos permite identificar padrões de variação de preços de combustíveis ao longo dos diferentes dias da semana.

# %% [markdown]
# ### Conversão e Distribuição dos Valores de Venda
#
# Convertemos a coluna 'Valor de Venda' para o tipo float, substituindo vírgulas por pontos para garantir a correta interpretação dos valores. Analisamos como os valores de venda de gasolina e etanol se distribuem ao longo dos dias da semana. Essa análise permite identificar possíveis padrões de variação nos preços e fatores que podem influenciar essa variação, como demanda ou eventos específicos.
#
# ### Remoção de Colunas Desnecessárias
# Prosseguindo com a otimização da análise, removemos colunas desnecessárias do DataFrame, utilizando o método drop. Isso resulta em um DataFrame mais limpo e focado nas informações cruciais para a análise dos preços de combustíveis. Essa abordagem aprimorada facilita a interpretação dos resultados e insights obtidos, concentrando-se nas informações mais relevantes.

# %% [markdown]
# ### Tratamentos Adicionais
#
# Carregamos os dados geográficos dos municípios, estados e regiões brasileiras para a plotagem dos mapas coropléticos utilizados nas análises.
#
# Para garantir a qualidade e consistência dos dados, realizamos a remoção de acentos e padronização da formatação da coluna "Municipio" no DataFrame baixado como shapefile, necessa´rio para a plotagem do mapa corplético com as coletas por município. Essa padronização é crucial para evitar problemas de correspondência durante a mesclagem de tabelas.
#
# Utilizamos a função remove_accent para remover acentos e caracteres especiais dos nomes dos municípios, além de converter os nomes para letras maiúsculas. Isso garante a padronização completa dos nomes dos municípios, evitando discrepâncias na mesclagem de dados.
#
# Realizamos a mesclagem (merge) entre os DataFrames de combustíveis e os arquivos shapefile. Essa mesclagem combina informações sobre combustíveis e características coletadas, proporcionando uma visão mais completa dos dados. Esse processo visa agregar informações geoespaciais aos dados de preços médios, possibilitando uma análise mais rica e abrangente.
# Através da fusão dos dados de preços médios com as geometrias dos estados e municípios, podemos visualizar de forma mais eficaz como os preços dos combustíveis variam geograficamente em todo o país. Essa integração permite identificar padrões espaciais e correlações entre os preços dos combustíveis e fatores geográficos ou econômicos específicos de cada estado.
# O resultado da fusão é um novo conjunto de dados, que inclui informações sobre as geometrias dos estados e os preços médios de gasolina aditivada, gasolina comum e etanol. Com esses dados combinados, podemos criar visualizações, mapas e análises espaciais que revelam insights interessantes sobre como os preços dos combustíveis estão distribuídos geograficamente.
#
# Essa integração entre dados de preços e informações geoespaciais é especialmente valiosa para planejamento estratégico, tomada de decisões no setor de combustíveis, políticas públicas e análises de mercado. Permite entender as disparidades nos preços entre diferentes regiões e explorar possíveis influências das características geográficas ou econômicas na formação dos preços dos combustíveis.

# %% [markdown]
# ### Exploração de Dados Geográficos e Análise de Preços de Combustíveis através de Mapa Coroplético
#
# Além de carregar e analisar os dados geográficos dos municípios brasileiros, expandimos nossa análise para incluir informações dos estados do país. Ao plotar um mapa coroplético, conseguimos visualizar de forma eficaz as diferenças na distribuição geográfica da estimativa da população em todo o Brasil, revelando áreas com densidades populacionais distintas.
# Ao empregar um mapa coroplético, associamos cores diferentes a intervalos específicos de valores de preços de combustíveis. Essa abordagem proporciona uma representação visual clara das variações de preços entre os estados brasileiros, permitindo uma análise instantânea das disparidades de custo.
#
# Utilizando as ferramentas que já empregamos anteriormente, como a biblioteca geopandas para manipulação geoespacial e a funcionalidade de matplotlib.colors para definir a escala de cores do mapa, podemos gerar um mapa coroplético de preços de combustíveis.
#
# Esse mapa oferecerá insights importantes sobre onde os preços dos combustíveis estão mais altos e mais baixos, identificando possíveis padrões geográficos nas tendências de preços. Essa visualização será uma valiosa adição à nossa análise, permitindo uma compreensão mais profunda das variações nos preços de combustíveis em todo o Brasil.
#
# ### Explorando Dados Geográficos dos Estados Brasileiros
#
# Nossa análise também se estende para os estados brasileiros, onde iremos explorar os preços médios de diferentes tipos de combustíveis utilizando um mapa coroplético. Para isso, consideremos que possuímos dados detalhados sobre os preços médios de combustíveis em cada estado.

# %% [markdown]
# ## <center> <font color = 'seagreen'> **Visualização de Distribuição de Coleta dos Dados** </font> </center>
#
# A visualização abaixo, exibe um mapa dos municípios do Brasil, onde os pontos coloridos indicam o tipo de combustível coletado em cada município. As cores dos pontos representam os diferentes tipos de combustível: Gasolina Aditivada (vermelho), Gasolina Comum (vermelho escuro) e Etanol (azul escuro).
#
# Com essa visualização, podemos compreender:
#
# - A distribuição dos diferentes tipos de combustível em todo o país.
#
# - Padrões regionais na presença de cada tipo de combustível.
#
# - Uma representação visual clara dos tipos de combustível em diferentes regiões.
#
# Esta visualização ajuda a identificar rapidamente a diversidade de tipos de combustível coletados em diferentes partes do país e a identificar padrões geográficos na distribuição desses tipos.

# %%
sc.panzer()

# %% [markdown]
# ### Análise da Regionalização das Áreas de Coletas
#
# Ao explorar a distribuição geográfica das áreas de coletas de combustíveis, observamos uma clara tendência de regionalização metropolitana. Esta tendência sugere que regiões mais densamente povoadas e metropolitanas, como o Sudeste e o Sul, apresentam maior concentração de pontos de coleta de combustíveis, enquanto regiões mais afastadas, como o Norte e áreas mais periféricas, tendem a ter menos dados coletados.
#
# Essa tendência é evidenciada nas visualizações geográficas, onde os pontos de coleta são mais densos e agrupados nas regiões metropolitanas. Por exemplo, áreas metropolitanas como São Paulo, Rio de Janeiro, Belo Horizonte e Porto Alegre apresentam uma alta concentração de pontos de coleta, indicando maior disponibilidade de dados nesses locais.
#
# Por outro lado, regiões mais distantes e menos densamente povoadas, como o Norte e algumas áreas periféricas, apresentam uma menor densidade de pontos de coleta. Isso pode ser influenciado por diversos fatores, como menor infraestrutura de coleta de dados, menor demanda ou acesso limitado a combustíveis em algumas regiões mais remotas.
#
# É importante considerar essas disparidades geográficas ao interpretar os resultados das análises. A falta de dados em algumas regiões pode impactar as conclusões sobre a variação de preços e padrões de consumo de combustíveis em nível nacional. Portanto, ao extrair insights e tomar decisões com base nessas análises, é fundamental considerar as diferenças regionais na disponibilidade de dados coletados.

# %% [markdown]
# ## <center> <font color = 'seagreen'> **Perguntas a serem Respondidas** </font> </center>
#
# ### 1. Como se comportaram os preços dos combustíveis durante os dois meses citados? Os valores tiveram uma tendência de queda ou diminuição?

# %% [markdown]
# A análise de tendência dos preços mostra o comportamento geral dos preços dos combustíveis ao longo dos meses de maio e junho de 2023. A oscilação percentual dos preços indica como os valores variaram em relação ao início do período. A variação de preços nos dois meses é calculada e expressa em percentual. Através desta análise, é possível identificar se os preços da gasolina e do etanol apresentaram uma tendência de queda ou diminuição durante o período analisado, bem como compreender as variações percentuais ocorridas. Para a construção mais linear do gráfico a seguir foi utilizado para preencher os dados faltantes (coletas realizadas aos sábados e domingos) o método Nearest, que completa com o valor mais próximo ao atual faltante, fornecendo uma melhor interpretação sem desvios ou valores fora da realidade observada.

# %%
sc.grafico_combustiveis()

# %% [markdown]
# - Análise Gráfica:
# O gráfico exibe a variação percentual nos preços dos combustíveis entre maio e junho. Cada tipo de combustível (Gasolina Aditivada, Gasolina Comum e Etanol) é representado por uma linha colorida.
# Os valores do início e do final do período são marcados com pontos coloridos nas respectivas linhas. Anotações com as oscilações percentuais são adicionadas próximo aos pontos finais das linhas.
# - Assim podemos compreender:
# O gráfico destaca visualmente as oscilações percentuais nos preços dos diferentes tipos de combustíveis entre os meses de maio e junho. As anotações fornecem informações detalhadas sobre as mudanças percentuais e o valor final. As datas foram formatadas de forma simplificada para facilitar a legibilidade. Com este gráfico, é possível compreender rapidamente as variações percentuais nos preços dos combustíveis ao longo dos dois meses analisados.
#
# O gráfico revelou que houve uma notável oscilação nos preços dos combustíveis, com especial destaque para o etanol, que apresentou a maior variação. No entanto, analisando os valores finais de gasolina aditivada, gasolina comum e etanol, observamos os seguintes comportamentos:
#
# - Gasolina Aditivada: Houve um aumento de 0.80% no preço entre maio e junho.
# - Gasolina Comum: Apresentou um aumento mais acentuado, com 1.72% de aumento no mesmo período.
# - Etanol: Contrariando a tendência de aumento nos preços dos outros combustíveis, o etanol apresentou uma queda significativa de -5.67%.
#
# Essas variações indicam que os preços dos combustíveis não seguiram uma tendência única e linear. Para entender melhor essa dinâmica, analisamos os acontecimentos externos que podem ter influenciado essas flutuações.
#
# As notícias destacam que a Petrobras anunciou, em meados de maio, uma redução nos preços da gasolina e do diesel vendidos às distribuidoras. Essa medida pode ter sido um fator que contribuiu para a queda inicial nos preços dos combustíveis durante o mês de maio. Além disso, uma mudança na cobrança do Imposto sobre Circulação de Mercadorias e Serviços (ICMS) pelos Estados também foi mencionada como um evento que impactou os preços dos combustíveis.
#
# A complexidade das oscilações nos preços dos combustíveis ao longo dos dois meses sugere que múltiplos fatores, incluindo eventos econômicos, mudanças regulatórias e flutuações nos preços internacionais do petróleo, desempenharam papéis significativos. Essa análise destaca a natureza dinâmica do mercado de combustíveis e a importância de considerar uma variedade de influências ao interpretar as variações nos preços.
#
# Em resumo, os preços dos combustíveis apresentaram uma oscilação considerável durante os meses analisados, com uma queda inicial seguida de um aumento posterior. A análise das notícias destaca que medidas econômicas e regulatórias podem ter sido fatores contribuintes para essas flutuações. Isso reforça a importância de considerar um conjunto diversificado de fatores ao analisar as tendências nos preços dos combustíveis.
#
# Fontes:
# - [Notícia 1](https://www.bbc.com/portuguese/articles/cx05kwvnyqno)
# - [Notícia 2](https://www.metropoles.com/negocios/combustiveis-inflacao-de-maio-e-junho-dara-tregua-mas-ipca-de-2023-nao-muda)

# %% [markdown]
# ### 2. Qual o preço médio dos combustíveis nesses dois meses?

# %% [markdown]
# Neste insight, calculamos e apresentamos o preço médio da Gasolina Comum, Gasolina Aditivada e Etanol nos meses de maio e junho de 2023.
#
# - Cálculo do Preço Médio:
#
#     Calculamos a média dos preços de venda da Gasolina Comum, Gasolina Aditivada e Etanol durante os dois meses.

# %%
print(f'Media Etanol: R$ {sc.media_combustivel[0]:.2f}\nMedia Gasolina Comum: R$ {sc.media_combustivel[1]:.2f}\nMédia Gasolina Aditivada R$ {sc.media_combustivel[2]:.2f}')
# Out:
# Media Etanol: R$ 4.06
# Media Gasolina Comum: R$ 5.39
# Média Gasolina Aditivada R$ 5.57

# %% [markdown]
# - Apresentação dos Resultados:
#
# Exibimos o preço médio dos combustíveis em reais por litro.
# Esses valores representam os preços médios cobrados pelos diferentes tipos de combustíveis durante o período analisado. Observamos que o etanol apresentou o preço médio mais baixo, enquanto a gasolina aditivada teve o preço médio mais alto.
#
# Essa análise dos preços médios dos combustíveis fornece uma visão geral dos custos médios enfrentados pelos consumidores ao abastecer seus veículos. É importante considerar esses valores médios ao tomar decisões relacionadas à compra de combustíveis e ao planejar orçamentos de transporte.
#
# Vale ressaltar que os preços médios podem variar entre diferentes regiões e postos de combustíveis, e também podem ser afetados por eventos econômicos e regulatórios. Portanto, embora esses sejam os preços médios calculados para o período de maio a junho, os preços reais podem ter variações específicas para diferentes locais e momentos.
#
# Em resumo, o preço médio dos combustíveis durante os meses analisados foi de R$ 5.39 para gasolina comum, R$ 4.060 para etanol e R$ 5.57 para gasolina aditivada. Esses valores fornecem uma referência útil para entender os custos médios enfrentados pelos consumidores ao abastecer seus veículos nesse período.

# %% [markdown]
# ### 3. Qual a frequência de coleta de dados por dia da semana?

# %% [markdown]
# A visualização  apresenta a variação do número de ocorrências de coleta de dados de combustíveis por dia da semana. Esta abordagem destaca as diferenças nas contagens de ocorrências em diferentes dias da semana, com ênfase nas linhas com os valores máximos e mínimos.
#
# - Contagem de Ocorrências por Dia da Semana:
# 1. O gráfico exibe a porcentagem de ocorrências de coleta de dados de combustíveis para cada dia da semana, apresentando uma visão geral da variação da atividade ao longo dos dias.
# 2. Destaque de Valores Extremos:
# As células com a maior e a menor contagem são destacadas. Isso permite a identificação rápida dos dias com a maior e menor atividade de coleta de dados.
# 3. Identificação de Padrões:
# O gráfico ajuda a identificar rapidamente quais dias da semana têm maior ou menor número de ocorrências, permitindo uma análise mais profunda de possíveis padrões ou tendências.
# 4. Comparações Visuais:
# A visualização gráfica é uma maneira eficaz de destacar valores extremos e identificar rapidamente os dias da semana com maior e menor atividade de coleta de dados. Isso facilita a análise e a compreensão dos padrões relacionados à variação do número de ocorrências por dia da semana, possibilitando insights valiosos para a tomada de decisões e análise futura.

# %%
sc.lancamento_dados()

# %% [markdown]
# Esses números representam o número de vezes que os preços dos combustíveis foram coletados e registrados para cada dia da semana. É importante notar que os dados aos finais de semana não são coletados, conforme esclarecido pela Agência Nacional de Petróleo e Gás Natural e Biocombustíveis (ANP) em fonte.
#
# Além disso, a distribuição da coleta de dados tende a ser mais variável e regionalizada em locais mais populosos. Isso pode ser observado na maior frequência de coleta de dados no início da semana, quando os números são mais altos. Essa variação na distribuição reflete as diferentes dinâmicas de consumo e abastecimento de combustíveis em diferentes regiões e áreas urbanas.
#
# A análise da frequência de coleta de dados por dia da semana oferece insights valiosos sobre os padrões de coleta da ANP. Ela destaca a importância de considerar a variabilidade temporal e regional ao interpretar os dados de preços dos combustíveis.
#
# Esses padrões podem ser úteis para a ANP e outras partes interessadas ao planejar estratégias de coleta de dados e análises futuras. Além disso, a compreensão das variações nos padrões de coleta pode ajudar a garantir que as análises sejam representativas e relevantes para os diferentes contextos regionais.
#
# Em resumo, a análise da frequência de coleta de dados por dia da semana durante os meses analisados mostrou uma distribuição variável, com maior coleta no início da semana. A ausência de coleta nos finais de semana e a variabilidade regional destacam a complexidade na obtenção de dados representativos sobre os preços dos combustíveis.
#
# Fonte:
# - [ANP esclarece metodologia de pesquisa de preços nos postos](https://www.novacana.com/noticias/anp-esclarece-metodologia-pesquisa-precos-postos-280623)

# %% [markdown]
# ### 4. Quais os 5 estados com o preço médio dos combustíveis mais caros?

# %% [markdown]
# Neste insight, identificamos os cinco estados que apresentam os preços médios mais caros de Gasolina Comum, Gasolina Aditivada e Etanol durante os meses de maio e junho de 2023.
#
# - Cálculo dos Preços Médios por Estado:
# Calculamos os preços médios de Gasolina Comum, Gasolina Aditivada e Etanol por estado.
# - Apresentação dos Resultados:
# Criamos DataFrames com os preços médios por estado para cada tipo de combustível.
# Ordenamos os estados de forma descendente pelo preço médio de cada combustível.

# %% [markdown]
# São apresentados os cinco estados com os preços médios mais caros de Gasolina Comum, Gasolina Aditivada e Etanol.
# Os estados são listados em ordem decrescente de preço médio para cada tipo de combustível.
# Através dessa análise, é possível identificar os estados onde os preços médios de combustíveis foram mais elevados durante os meses de maio e junho de 2023.

# %% [markdown]
# Neste insight, criamos um gráfico de barras horizontal que compara os cinco estados com os preços médios mais caros de Gasolina Aditivada, Gasolina Comum e Etanol durante os meses de maio e junho de 2023.
# O gráfico possui três subplots (um para cada tipo de combustível: Gasolina Aditivada, Gasolina Comum e Etanol).
# Cada subplot contém barras horizontais que representam os estados com os preços médios mais caros.
# As barras são coloridas de acordo com o tipo de combustível.
# Os valores de preço são exibidos nas barras.
# O título do gráfico informa qual combustível está sendo representado.

# %%
sc.estados_maior_preco()

# %% [markdown]
# Essa variação nos preços dos combustíveis entre os estados brasileiros pode ser influenciada por diversos fatores, incluindo a tributação estadual e federal. A tabela da carga tributária dos combustíveis por estado, detalhando os tributos federais e estaduais, pode ser consultada em fonte. Atributos como logística de distribuição, custos operacionais, política tributária e demanda local também podem contribuir para as diferenças nos preços.
#
# É importante considerar esses fatores ao avaliar as razões por trás dos preços mais altos em determinados estados. A tributação, em particular, desempenha um papel crucial na composição dos preços dos combustíveis.
#
# Em resumo, a análise dos cinco estados com os preços médios mais caros para diferentes tipos de combustíveis fornece uma visão dos estados onde os consumidores enfrentam preços mais elevados, levando em consideração fatores como tributação, logística e dinâmicas de mercado.
#
# Fonte:
# - [Tabela de Carga Tributária dos Combustíveis por Estado](https://www.fecombustiveis.org.br/tributacao)

# %% [markdown]
# ### 5. Qual o preço médio dos combustíveis por estado?

# %% [markdown]
# Neste insight, exploramos a variação nos preços médios de diferentes tipos de combustíveis, como gasolina aditivada, gasolina comum e etanol, em diferentes estados. O objetivo é entender como os preços variam de estado para estado, identificando padrões ou discrepâncias significativas.
# Para isso, criamos um DataFrame que contém os preços médios da gasolina aditivada, gasolina comum e etanol para cada estado. Em seguida, arredondamos os valores para duas casas decimais para facilitar a visualização.
#
# Este insight é útil para consumidores, analistas de mercado e formuladores de políticas públicas, pois fornece informações sobre como os preços dos combustíveis impactam diferentes regiões do país. Pode ajudar na compreensão das razões por trás das variações nos preços, como impostos locais, logística de transporte e disponibilidade de matéria-prima.
# A análise dos preços médios por estado pode revelar insights importantes, como estados onde os preços são mais altos ou mais baixos em comparação com a média nacional, bem como tendências sazonais ou padrões regionais.

# %%
sc.media_gasolina_adit()

# %% [markdown]
# Neste insight, criamos uma visualização que permite comparar o preço médio da gasolina aditivada em diferentes estados do Brasil. Usamos uma abordagem combinada de mapas coropléticos e gráficos de barras horizontais para fornecer uma representação abrangente e visualmente atraente dos preços da gasolina aditivada em todo o país.
# A figura gerada contém dois componentes principais: um mapa coroplético que mostra a variação espacial dos preços médios da gasolina aditivada, e um gráfico de barras horizontais que complementa a visualização com uma representação ordenada dos preços médios em formato de barras.
# No mapa coroplético:
# As cores mais claras representam preços mais baixos e as cores mais escuras representam preços mais altos.
# Cada estado é preenchido com uma cor que indica seu preço médio da gasolina aditivada.
# Não há legendas, uma vez que a cor é suficiente para transmitir a informação visualmente.
# No gráfico de barras horizontais:
# Os estados estão listados verticalmente no eixo y, com os preços médios da gasolina aditivada representados horizontalmente.
# As barras estão coloridas de acordo com uma escala de cores que reflete a variação nos preços.
# Valores em reais (R$) são exibidos no topo de cada barra para facilitar a leitura.
# O eixo x não exibe valores, concentrando-se apenas na representação gráfica dos preços.
# O título centralizado da figura reforça o foco na análise do preço médio da gasolina aditivada por estado, adicionando um elemento estilístico em itálico para destacar o título.
# Essa visualização é poderosa para identificar rapidamente quais estados têm os preços médios mais altos e mais baixos de gasolina aditivada, além de possibilitar comparações visuais entre diferentes regiões do país.
# Lembrando que o código e a figura acima são uma representação ilustrativa, portanto, certifique-se de adaptá-los aos seus dados reais e à biblioteca de visualização que você está usando (como o matplotlib).

# %%
sc.media_gasolina()

# %% [markdown]
# Neste insight, apresentamos uma figura que oferece uma visão abrangente e comparativa do preço médio da gasolina comum em diferentes estados do Brasil. Assim como no insight anterior, utilizamos uma abordagem combinada de mapas coropléticos e gráficos de barras horizontais para facilitar a compreensão e a análise visual dos preços da gasolina comum em todo o país.
# A figura gerada inclui dois componentes principais:
# No mapa coroplético:
# Cada estado é colorido de acordo com o seu preço médio da gasolina comum.
# A escala de cores vai desde os preços mais baixos (representados por cores mais claras) até os preços mais altos (cores mais escuras).
# O mapa não apresenta legendas, uma vez que as cores são suficientes para transmitir a informação visualmente.
# No gráfico de barras horizontais:
# Os estados estão listados verticalmente no eixo y, com os preços médios da gasolina comum representados horizontalmente.
# As barras são coloridas de acordo com uma escala de cores que reflete a variação nos preços.
# Valores em reais (R$) são exibidos no topo de cada barra para facilitar a leitura.
# O eixo x não exibe valores, concentrando-se apenas na representação gráfica dos preços.
# O título centralizado da figura destaca a análise do preço médio da gasolina comum por estado, acrescentando um toque estilístico em itálico para enfatizar o título.
# Essa visualização é eficaz para identificar rapidamente os estados com os preços médios mais altos e mais baixos de gasolina comum, permitindo comparações visuais e insights sobre a distribuição geográfica dos preços.
# Lembrando que o código e a figura acima são apenas uma representação ilustrativa. Certifique-se de adaptá-los aos seus dados reais e à biblioteca de visualização que você está usando (como o matplotlib).

# %%
sc.media_etanol()

# %% [markdown]
# Neste insight, apresentamos uma figura que oferece uma análise comparativa do preço médio do etanol em diferentes estados do Brasil. Continuamos a utilizar uma abordagem que combina mapas coropléticos com gráficos de barras horizontais, permitindo uma compreensão abrangente e visual dos preços do etanol em todo o país.
# A figura gerada inclui dois componentes principais:
# No mapa coroplético:
# Cada estado é colorido de acordo com o seu preço médio do etanol.
# A escala de cores vai desde os preços mais baixos (representados por cores mais claras) até os preços mais altos (cores mais escuras).
# O mapa não apresenta legendas, já que as cores são suficientes para transmitir a informação visualmente.
# No gráfico de barras horizontais:
# Os estados estão listados verticalmente no eixo y, com os preços médios do etanol representados horizontalmente.
# As barras são coloridas de acordo com uma escala de cores que reflete a variação nos preços.
# Valores em reais (R$) são exibidos no topo de cada barra para facilitar a leitura.
# O eixo x não exibe valores, concentrando-se apenas na representação gráfica dos preços.
# O título centralizado da figura enfatiza a análise do preço médio do etanol por estado, adicionando um toque estilístico em itálico para destacar o título.
# Essa visualização é útil para identificar rapidamente quais estados possuem os preços médios mais altos e mais baixos do etanol, além de permitir comparações visuais e insights sobre a distribuição geográfica dos preços.
# Lembrando que o código e a figura acima são apenas uma representação ilustrativa. Certifique-se de adaptá-los aos seus dados reais e à biblioteca de visualização que você está usando (como o matplotlib).

# %% [markdown]
# Os valores destacam as médias de preço de cada tipo de combustível nos estados listados. Esses preços médios refletem uma combinação de fatores, incluindo tributação estadual e federal, custos de produção, logística de distribuição e dinâmicas de mercado.
#
# A tabela da carga tributária dos combustíveis por estado, que detalha os tributos federais e estaduais, pode ser consultada em fonte. Atributos como logística de distribuição, custos operacionais, política tributária e demanda local também podem contribuir para as diferenças nos preços.
#
# A análise desses preços médios por estado oferece insights valiosos sobre as variações regionais nos preços dos combustíveis. Essas variações podem influenciar decisões de abastecimento e impactar o orçamento dos consumidores em diferentes estados.
#
# Em resumo, a análise dos preços médios dos combustíveis por estado destaca as variações nas médias de preços para a Gasolina Comum, Gasolina Aditivada e Etanol em diferentes regiões do Brasil.
#
# Fonte:
# - [Tabela de Carga Tributária dos Combustíveis por Estado](https://www.fecombustiveis.org.br/tributacao)

# %% [markdown]
# ### 6. Qual o município que possui o menor preço para os combustíveis?

# %% [markdown]
# Neste insight, exploramos os municipios que possuem os menores preços médios de gasolina aditivada, gasolina comum e etanol.

# %% [markdown]
# Essa análise dos menores preços de combustíveis pode ser útil para os consumidores que desejam encontrar os melhores preços em diferentes tipos de combustíveis e localidades. Além disso, também pode ser útil para análises de mercado e para identificar possíveis padrões nos preços praticados.

# %%
sc.municipios_baratos()

# %% [markdown]
# Analisando os dados, identificamos os municípios que possuem os menores preços médios para os diferentes tipos de combustíveis nos meses de maio e junho:
#
# - **Gasolina:**
#   O município com o menor preço médio de Gasolina foi **Jacareí**, com um valor de aproximadamente R$ 4.93 por litro. Na sequência, temos Taubaté com um preço médio de cerca de R$ 4.95 por litro, seguido por Amarante do Maranhão com R$ 4.97 por litro.
#
# - **Gasolina Aditivada:**
#   O município com o menor preço médio de Gasolina Aditivada foi **Lajedo**, com um valor de aproximadamente R$ 5.10 por litro. Em segundo lugar, temos Garça com um preço médio de cerca de R$ 5.11 por litro, seguido por São José dos Campos com R$ 5.12 por litro.
#
# - **Etanol:**
#   O município com o menor preço médio de Etanol foi **Adamantina**, com um valor de aproximadamente R$ 3.37 por litro. Na sequência, temos Birigui com um preço médio de cerca de R$ 3.40 por litro, seguido por Várzea Grande com R$ 3.47 por litro.
#
# Esses valores refletem os municípios com os preços médios mais baixos para cada tipo de combustível durante o período analisado. Esses preços podem ser influenciados por diversos fatores, incluindo a concorrência local, custos operacionais, política tributária e dinâmicas de mercado.
#
# É importante observar que os preços dos combustíveis podem variar significativamente de um município para outro, e a análise desses preços médios oferece insights sobre as opções mais acessíveis para os consumidores em diferentes localidades.

# %% [markdown]
# ### 7. Qual o município que possui o maior preço para os combustíveis?

# %% [markdown]
# Neste insight, continuamos a análise exploratória dos preços de combustíveis, focando agora nos registros que possuem os maiores preços médios de gasolina aditivada, gasolina comum e etanol. Utilizamos os DataFrames para identificamos os registros que possuem os preços mais altos para cada um deles.

# %% [markdown]
# Essa análise dos maiores preços de combustíveis pode ser útil para identificar os locais onde os preços são mais elevados, bem como para monitorar tendências de preços mais altos em diferentes produtos e datas de coleta.

# %%
sc.municipios_caros()

# %% [markdown]
# Analisando os dados, identificamos os municípios que possuem os maiores preços médios para os diferentes tipos de combustíveis nos meses de maio e junho:
#
# - **Gasolina:**
#   O município com o maior preço médio de Gasolina foi **Tefé**, com um valor de aproximadamente R$ 6.99 por litro. Em segundo lugar, temos Parintins com um preço médio de cerca de R$ 6.88 por litro, seguido por Cruzeiro do Sul com R$ 6.49 por litro.
#
# - **Gasolina Aditivada:**
#   O município com o maior preço médio de Gasolina Aditivada foi **Tefé**, com um valor de aproximadamente R$ 6.97 por litro. Em segundo lugar, temos Parintins com um preço médio de cerca de R$ 6.95 por litro, seguido por Cruzeiro do Sul com R$ 6.57 por litro.
#
# - **Etanol:**
#   O município com o maior preço médio de Etanol foi **Bagé**, com um valor de aproximadamente R$ 5.76 por litro. Em segundo lugar, temos Santa Cruz do Sul com um preço médio de cerca de R$ 5.52 por litro, seguido por Santarém com R$ 5.51 por litro.
#
# Esses valores refletem os municípios com os preços médios mais altos para cada tipo de combustível durante o período analisado. Assim como nos casos dos menores preços, esses preços mais elevados podem ser influenciados por diversos fatores, como custos operacionais, logística de distribuição, política tributária e dinâmicas de mercado.
#
# A análise desses preços médios mais altos por município oferece insights sobre as localidades onde os combustíveis são mais caros, o que pode impactar o orçamento dos consumidores dessas regiões.

# %% [markdown]
# ### 8. Qual a região que possui o maior valor médio da gasolina (comum e aditivada)?

# %% [markdown]
# Neste insight, realizamos uma análise do valor médio dos combustíveis (gasolina aditivada, gasolina comum e etanol) por região do Brasil.
# Os principais passos desse insight são:
# 1-Calculamos o valor médio da gasolina aditivada, gasolina comum e etanol por região, agrupando os registros por região e calculando a média dos valores de venda.
# 2-Criamos um DataFrame que reúne os valores médios por região para cada tipo de combustível.
# 3-Arredondamos os valores para duas casas decimais para melhor apresentação.
# 5-Aplicamos a formatação condicional a todas as colunas do DataFrame de valores médios por região.

# %% [markdown]
# Este insight é útil para entender como os preços médios dos combustíveis variam entre as diferentes regiões do Brasil e identificar regiões com valores extremos. Isso pode ser valioso para análises de mercado, tomada de decisões estratégicas e planejamento logístico.

# %%
sc.grafico_regiao()

# %% [markdown]
# Ao analisar os dados separadamente para cada tipo de gasolina (comum e aditivada), observamos as seguintes informações sobre a região com o maior valor médio para cada tipo de gasolina nos meses de maio e junho:
#
# * **Gasolina Comum:**
#
# A região com o maior valor médio da gasolina comum nos meses analisados foi a **Região Norte**, com um valor médio de aproximadamente R$ 5.78 por litro. Em seguida, temos as outras regiões com seus respectivos valores médios da gasolina comum:
#
#   - Região Nordeste: Valor médio de gasolina comum de aproximadamente R$ 5.45 por litro.
#
#   - Região Sudeste: Valor médio de gasolina comum de aproximadamente R$ 5.31 por litro.
#
#   - Região Centro-Oeste: Valor médio de gasolina comum de aproximadamente R$ 5.38 por litro.
#
#   - Região Sul: Valor médio de gasolina comum de aproximadamente R$ 5.43 por litro.
#
# * **Gasolina Aditivada:**
#
# A região com o maior valor médio da gasolina aditivada nos meses analisados foi a Região Norte, com um valor médio de aproximadamente R$ 5.95 por litro. Em seguida, temos as outras regiões com seus respectivos valores médios da gasolina aditivada:
#
#   - Região Nordeste: Valor médio de gasolina aditivada de aproximadamente R$ 5.59 por litro.
#
#   - Região Sudeste: Valor médio de gasolina aditivada de aproximadamente R$ 5.53 por litro.
#
#   - Região Centro-Oeste: Valor médio de gasolina aditivada de aproximadamente R$ 5.52 por litro.
#
#   - Região Sul: Valor médio de gasolina aditivada de aproximadamente R$ 5.58 por litro.
#
# Esses valores indicam as diferenças regionais nos preços médios da gasolina comum e aditivada ao longo dos dois meses analisados. A análise separada por tipo de gasolina permite compreender como os preços variam de acordo com a região e oferece insights sobre as dinâmicas específicas de mercado que afetam cada tipo de combustível.

# %% [markdown]
# ### 9. Qual a região que possui o menor valor médio do etanol?

# %% [markdown]
# Neste insight, realizamos uma análise para identificar a região do Brasil que possui o menor valor médio do etanol. Para isso, seguimos os seguintes passos:
# 1-Calculamos o valor médio do etanol por região, como feito anteriormente.
# 2-Utilizamos função para identificar a região com o menor valor médio do etanol.
# 3-Obtivemos o valor médio correspondente à região com o menor valor médio do etanol.
# 4-Exibimos o resultado de forma formatada, destacando a região com o menor valor médio e o valor médio em reais (R$) com duas casas decimais.

# %% [markdown]
# Este insight é relevante para entender quais regiões têm os menores preços médios de etanol, o que pode ser útil para análises de mercado, decisões estratégicas e planejamento logístico relacionados ao abastecimento com etanol. Além disso, pode fornecer insights sobre a acessibilidade e a preferência dos consumidores por etanol em diferentes partes do país.

# %% [markdown]
# Ao analisar os dados já exibidos na resposta anterior, identificamos que a região com o menor valor médio do etanol nos meses de maio e junho foi a Região Centro-Oeste, com um valor médio de aproximadamente R$ 3.87 por litro.
#
# Em seguida, temos as outras regiões com seus respectivos valores médios do etanol:
#
#   - Região Sudeste: Valor médio de etanol de aproximadamente R$ 3.90 por litro.
#
#   - Região Sul: Valor médio de etanol de aproximadamente R$ 4.42 por litro.
#
#   - Região Nordeste: Valor médio de etanol de aproximadamente R$ 4.41 por litro.
#
#   - Região Norte: Valor médio de etanol de aproximadamente R$ 4.72 por litro.
#
# Esses valores indicam as diferenças regionais nos preços médios do etanol ao longo dos dois meses analisados. A análise por região permite compreender como os preços do etanol variam geograficamente e oferece insights sobre os fatores que influenciam essas variações, como a disponibilidade de matéria-prima e a competição no mercado local.

# %% [markdown]
# ### 10. Há alguma correlação entre o valor dos combustíveis e a região onde ele é vendido?

# %% [markdown]
# O Insight explora a possível correlação entre o valor dos combustíveis e a região onde são vendidos, considerando três tipos diferentes de combustíveis: gasolina aditivada, gasolina comum e etanol. Para isso, foram selecionados os valores de venda, a região e a data da coleta dos dados para cada tipo de combustível. A análise visa identificar se há algum padrão ou tendência nos preços dos combustíveis em diferentes regiões.

# %% [markdown]
# Podemos conferir um insight e análise interessante da correlação entre os preços médios de venda da gasolina aditivada em diferentes regiões ao longo do tempo.
#
# 1. Pivot Table: O primeiro passo cria uma tabela dinâmica (pivot table). Essa tabela apresenta os preços médios de venda da gasolina aditivada, agrupados por região e ao longo do tempo (data da coleta).
#
# 2. Dropna(): O método dropna() é usado para remover linhas que contenham valores ausentes (NaN) da tabela pivot. Isso é importante para garantir que a análise da correlação seja baseada em dados completos.
#
# 3. Correlação: A função corr() é aplicada à tabela pivot resultante após a remoção de valores ausentes. Ela calcula a matriz de correlação entre as diferentes regiões. A matriz de correlação mostra como os preços médios de venda das diferentes regiões estão relacionados entre si, variando de -1 (correlação negativa perfeita) a 1 (correlação positiva perfeita).

# %% [markdown]
# Com esse insight você obterá uma matriz de correlação entre as regiões, indicando como os preços médios de venda da gasolina aditivada em diferentes regiões estão correlacionados. Cada célula da matriz representará a correlação entre duas regiões específicas.

# %% [markdown]
# Nesse insight temos algumas observações.
#
# 1. Correlações Positivas ou Negativas: Os valores na matriz de correlação indicarão se há uma relação positiva ou negativa entre os preços médios de venda nas diferentes regiões. Uma correlação positiva sugere que os preços tendem a se mover na mesma direção em ambas as regiões, enquanto uma correlação negativa indica que os preços tendem a se mover em direções opostas.
#
# 2. Padrões Temporais: Além das correlações entre regiões, você pode observar se há algum padrão temporal nas correlações ao longo do tempo. Algumas regiões podem ter correlações mais fortes em determinados períodos, o que pode ser influenciado por fatores sazonais, econômicos ou políticos.
#
# 3. Identificação de Tendências Regionais: Você pode identificar regiões que têm preços médios de venda altamente correlacionados, o que pode indicar tendências regionais compartilhadas que afetam os preços dos combustíveis.

# %% [markdown]
# Foi criado um mapa de calor (heatmap) que visualiza a matriz de correlação entre os preços médios de venda da gasolina aditivada em diferentes regiões. Abaixo está uma descrição detalhada do código e o insight gerado pelo mapa de calor:

# %%
sc.correlacao_combustivel()

# %% [markdown]
# O mapa de calor criado fornece uma representação visual da matriz de correlação entre os preços médios de venda da gasolina aditivada, gasolina comum e etanol em diferentes regiões. Através das cores e dos números exibidos nas células do mapa de calor, é possível identificar padrões de correlação entre as regiões.
#
# 1. Cores: As cores no mapa de calor indicam a intensidade da correlação entre as regiões. As cores mais escuras representam correlações mais fortes, enquanto as cores mais claras  representam correlações mais fracas.
#
# 2. Valores Numéricos: Os números nas células do mapa de calor (definidos pelo parâmetro annot=True) indicam os valores de correlação entre as regiões. Esses valores podem variar de -1 (correlação negativa perfeita) a 1 (correlação positiva perfeita).
#
# Com base no mapa de calor, você pode identificar visualmente quais regiões têm correlações mais fortes ou mais fracas em relação aos preços médios de venda da gasolina aditivada. Isso pode ajudar a identificar agrupamentos regionais ou padrões de comportamento que afetam os preços da gasolina aditivada em diferentes partes do país ou da área geográfica de interesse.

# %% [markdown]
# Ao analisar a correlação entre o valor dos combustíveis (gasolina comum, gasolina aditivada e etanol) e a região onde eles são vendidos, observamos os seguintes padrões:
#
# - **Gasolina Comum:**
#
#   A gasolina comum apresenta uma correlação mais forte com a região Sudeste, com um valor de correlação de aproximadamente 0.69. Isso indica que existe uma associação positiva moderada entre o valor da gasolina comum e a região Sudeste, ou seja, à medida que o valor da gasolina comum aumenta, o valor da gasolina comum na região Sudeste também tende a aumentar.
#
# - **Gasolina Aditivada:**
#
#   A gasolina aditivada também possui uma correlação significativa com a região Sudeste, com um valor de correlação de aproximadamente 0.71. Isso indica uma associação positiva moderada entre o valor da gasolina aditivada e a região Sudeste.
#
# - **Etanol:**
#
#   O etanol apresenta a maior correlação com a região Sudeste, com um valor de correlação de aproximadamente 0.90. Isso sugere uma associação forte e positiva entre o valor do etanol e a região Sudeste.
#
# Em geral, podemos concluir que existe uma correlação positiva moderada a forte entre o valor dos combustíveis e a região Sudeste. Isso pode indicar que fatores específicos da região Sudeste, como demanda, oferta, infraestrutura e políticas locais, podem ter um impacto mais significativo nos preços dos combustíveis nessa região.
#
# Por outro lado, as correlações com as outras regiões (Centro-Oeste, Nordeste, Norte e Sul) são mais variáveis e menos consistentes entre os diferentes tipos de combustíveis. É importante notar que correlações não indicam causalidade direta, e outras variáveis podem estar contribuindo para esses padrões.

# %% [markdown]
# Ao explorar a correlação dos preços médios de venda dos combustíveis em diferentes regiões, podemos destacar informações valiosas:
#
# 1. Associações Regionais Identificadas: A análise da correlação destaca associações entre as regiões no que diz respeito aos preços médios de venda do etanol. Regiões com correlações mais fortes, indicadas por cores mais escuras no mapa de calor, sugerem uma tendência de preços semelhantes entre essas áreas.
# 2. Associações Positivas e Negativas: As células do mapa de calor, anotadas com valores numéricos de correlação, refletem se os preços médios de venda do etanol nas diferentes regiões têm uma correlação positiva (aumentam ou diminuem juntos) ou negativa (um aumenta enquanto o outro diminui). Isso pode indicar fatores regionais comuns que afetam os preços do etanol.
# 3. Identificação de Tendências e Padrões Temporais: Além das associações estáticas, é possível identificar se as correlações mudam ao longo do tempo. Essas variações temporais podem ser influenciadas por fatores sazonais, flutuações na demanda ou eventos econômicos específicos.
# 4. Comparações com Outros Combustíveis: Comparar a correlação do etanol com outros combustíveis (como gasolina aditivada e gasolina comum) pode ajudar a identificar diferenças nos padrões de preços entre os tipos de combustível e suas correlações com as regiões.
# 5. Identificação de Outliers Regionais: Correlações excepcionalmente baixas ou negativas podem indicar regiões que têm comportamentos de preços divergentes em relação às demais. Isso pode ser resultado de fatores regionais específicos que influenciam os preços do etanol.
#
# A visualização da correlação por meio de um mapa de calor facilita a identificação desses padrões e tendências. Ajuda a explorar rapidamente as relações entre as regiões e a compreender como os preços médios de venda do etanol se comportam em diferentes partes do país ou da área geográfica de interesse.

# %% [markdown]
# ### 11. Quais as bandeiras mais caras?

# %% [markdown]
# Ao analisar os dados das bandeiras de postos de combustíveis em relação aos preços médios dos diferentes tipos de combustíveis, observamos que as bandeiras mais caras em relação à gasolina aditivada, gasolina comum e etanol são:
#
# - **Gasolina Aditivada:**
#
# **Bandeira RAIZEN:** Com um valor médio de aproximadamente R$ 5.69 por litro e uma porcentagem de dados de cerca de 29.02%.
#
# **Bandeira IPIRANGA:** Com um valor médio de aproximadamente R$ 5.64 por litro e uma porcentagem de dados de cerca de 24.11%.
#
# **Bandeira VIBRA ENERGIA:** Com um valor médio de aproximadamente R$ 5.63 por litro e uma porcentagem de dados de cerca de 23.04%.

# %%
sc.grafico_correlacao('#d11507','correlação GASOLINA ADITIVADA','GASOLINA ADITIVADA')

# %% [markdown]
# - **Gasolina Comum:**
#
# **Bandeira VIBRA ENERGIA:** Com um valor médio de aproximadamente R$ 5.48 por litro e uma porcentagem de dados de cerca de 34.71%.
#
# **Bandeira IPIRANGA:** Com um valor médio de aproximadamente R$ 5.46 por litro e uma porcentagem de dados de cerca de 21.19%.
#
# **Outras Bandeiras (Agrupamento das bandeiras menos presentes) :** Com um valor médio de aproximadamente R$ 5.43 por litro e uma porcentagem de dados de cerca de 9,23%.

# %%
sc.grafico_correlacao('#a51b0b','correlação GASOLINA','GASOLINA')

# %% [markdown]
# - **Etanol:**
#
# **Outras Bandeiras (Agrupamento das bandeiras menos presentes):** Com um valor médio de aproximadamente R$ 4.29 por litro e uma porcentagem de dados de cerca de 8,15%.
#
# **Bandeira VIBRA ENERGIA:** Com um valor médio de aproximadamente R$ 4.20 por litro e uma porcentagem de dados de cerca de 20.38%.
#
# **Bandeira IPIRANGA:** Com um valor médio de aproximadamente R$ 4.09 por litro e uma porcentagem de dados de cerca de 20.68%.
#
# A análise das bandeiras é relevante para orientar os consumidores na escolha do posto de combustível com base em critérios como preço e qualidade do combustível.

# %%
sc.grafico_correlacao('royalblue','correlação ETANOL','ETANOL')

# %% [markdown]
# Os gráficos também mostram a quantidade de registros dos combustíveis para cada bandeira de estação de serviço, destacando as principais marcas e suas respectivas participações no mercado.
# A porcentagem de dados representados por cada bandeira (porcentagem dos dados em relação ao total) é calculada e apresentada como [Participação de Mercado].
#
# A visualização também inclui o valor médio de venda por litro para cada uma das 5 principais bandeiras. Isso permite uma comparação direta dos preços médios entre as marcas mais representativas.
#
# Além das 5 principais bandeiras, a categoria "Outros" representa a soma dos dados de todas as outras bandeiras que não fazem parte do grupo das 5 principais. Ela mostra a participação combinada dessas bandeiras menos representativas.
#
# A identificação das principais bandeiras ajuda a entender quais marcas são líderes no mercado dos combustíveis e como suas estratégias de preços e presença regional podem influenciar as tendências de consumo e as preferências dos clientes.
#
# Com base nos valores médios de venda por litro, é possível comparar as estratégias de precificação das principais bandeiras. Isso pode fornecer insights sobre como diferentes marcas se posicionam em termos de preços e competitividade.
#
# Essa análise oferece uma visão abrangente das principais bandeiras, permitindo avaliar a participação de mercado, comportamento de preços e preferências dos consumidores em relação às diferentes marcas.

# %% [markdown]
# ### 12. Há alguma correlação entre o valor dos combustíveis e a bandeira que vende ele?

# %% [markdown]
# A análise de correlação entre o valor dos combustíveis e a bandeira das estações de venda pode proporcionar insights interessantes sobre os padrões de preço associados a diferentes marcas. Aqui está uma análise que pode ser realizada em relação aos três tipos de combustíveis (Gasolina Aditivada, Gasolina Comum e Etanol):
#
# 1. Identificação de Tendências de Preço por Bandeira: Ao analisar a correlação entre o valor dos combustíveis e a bandeira da estação de venda, é possível identificar se determinadas marcas têm preços consistentemente mais altos ou mais baixos em relação às outras. Uma correlação positiva poderia sugerir que uma determinada bandeira está associada a preços mais altos, enquanto uma correlação negativa indicaria o oposto.
#
# 2. Identificação de Outliers e Variações: A análise de correlação pode ajudar a identificar possíveis outliers ou variações extremas nos preços de combustíveis de uma determinada bandeira em comparação com as demais. Essas variações podem ser resultado de estratégias de preços específicas adotadas por uma marca.
#
# 3. Comparação entre Tipos de Combustíveis: Ao aplicar essa análise aos três tipos de combustíveis (Gasolina Aditivada, Gasolina Comum e Etanol), você pode comparar como diferentes bandeiras influenciam os preços de cada tipo. Isso pode revelar comportamentos específicos associados a cada produto.
#
# 4. Influências Regionais vs. Influências da Bandeira: A análise pode ajudar a discernir se as variações nos preços são mais fortemente influenciadas pelas características regionais ou pelas bandeiras de venda. Isso pode fornecer insights sobre como os fatores locais e as estratégias de preços das marcas interagem.
#
# 5. Aprofundamento da Análise: Além da correlação, você também pode explorar outras métricas estatísticas, como médias e desvios padrão, para ter uma visão mais completa das diferenças de preço entre as bandeiras.

# %% [markdown]
# Ao analisar a correlação entre os valores dos combustíveis (gasolina aditivada, gasolina comum e etanol) e as diferentes bandeiras de postos de combustíveis, podemos observar os seguintes resultados:
#
# - **Gasolina Aditivada:**
#   - As bandeiras "IPIRANGA" e "VIBRA ENERGIA" apresentam uma correlação relativamente forte e positiva com os preços da gasolina aditivada. Isso pode indicar que os preços da gasolina aditivada nesses postos tendem a aumentar ou diminuir em conjunto.
#   - A bandeira "RAIZEN" também apresenta uma correlação significativa, porém um pouco mais fraca, com os preços da gasolina aditivada.
#   - As bandeiras "BRANCA" (sem bandeira) e "Outras" têm correlações positivas menos fortes com os preços da gasolina aditivada.
# - **Gasolina Comum:**
#   - As bandeiras "IPIRANGA" e "VIBRA ENERGIA" também apresentam uma correlação relativamente forte e positiva com os preços da gasolina comum.
#   - A bandeira "RAIZEN" mostra uma correlação moderada com os preços da gasolina comum.
#   - As bandeiras "BRANCA" e "Outras" têm correlações positivas menos fortes em relação aos preços da gasolina comum.
# - **Etanol:**
#   - A bandeira "IPIRANGA" apresenta uma correlação forte e positiva com os preços do etanol.
#   - As bandeiras "VIBRA ENERGIA" e "RAIZEN" também têm correlações positivas, porém um pouco mais fracas, com os preços do etanol.
#   - As bandeiras "BRANCA" e "Outras" têm correlações positivas menos fortes em relação aos preços do etanol.
#
# Essas correlações indicam que as bandeiras de postos de combustíveis podem ter uma influência na determinação dos preços dos diferentes tipos de combustíveis. No entanto, é importante lembrar que a correlação não implica necessariamente em causalidade. Outros fatores, como localização dos postos, políticas de precificação e demanda local, também podem contribuir para as variações nos preços dos combustíveis.

# %% [markdown]
# ### 13. O valor do petróleo influencia no valor da gasolina?
#
# Para avaliar a influência do valor do petróleo no valor da gasolina, examinamos os preços de abertura do petróleo Brent por semana em maio de 2023 e os valores médios de venda da gasolina comum por semana em maio e junho de 2023. Vamos analisar os padrões observados:

# %%
sc.petro()

# %% [markdown]
#  **Maio de 2023:**
#
#   Ao comparar os preços de abertura do petróleo Brent com os valores médios de venda da gasolina comum por semana em maio, não parece haver uma correlação clara entre essas duas variáveis.
#   Embora haja algumas flutuações nos preços de abertura do petróleo e nos valores médios da gasolina comum ao longo do mês, não há uma tendência evidente de que os aumentos ou diminuições nos preços do petróleo estejam diretamente associados às variações nos preços da gasolina comum.

# %%
sc.gasolina_5()

# %% [markdown]
# - **Junho de 2023:**
#
#   A análise dos valores médios de venda da gasolina comum por semana em junho também não indica uma relação direta entre as flutuações nos preços do petróleo e as variações nos preços da gasolina.
#   Embora os preços de abertura do petróleo Brent e os valores da gasolina comum possam ter algumas oscilações semelhantes, não é possível afirmar que uma mudança específica nos preços do petróleo resulte em mudanças proporcionais nos preços da gasolina.

# %%
sc.gasolina_6()

# %% [markdown]
# No geral, os dados analisados não indicam uma correlação direta e óbvia entre os preços do petróleo e os preços da gasolina. Outros fatores, como questões de oferta e demanda, políticas de precificação dos postos de combustíveis e flutuações cambiais, também podem desempenhar um papel significativo nas variações nos preços da gasolina.
#
# Ao analisar a possível influência do valor do petróleo no valor da gasolina, é importante considerar que a análise foi realizada em um período relativamente curto, abrangendo os meses de maio e junho de 2023. Esse período limitado pode introduzir vieses de avaliação, uma vez que as flutuações de preços em um curto espaço de tempo podem não capturar totalmente os efeitos de médio e longo prazo.
#
# Durante o período analisado, não ficou evidente uma correlação direta entre os preços de abertura do petróleo Brent e os valores médios de venda da gasolina comum. No entanto, é importante ressaltar que as dinâmicas do mercado de combustíveis são complexas e influenciadas por diversos fatores, como as políticas de precificação dos postos, oscilações cambiais, questões de oferta e demanda e até mesmo fatores geopolíticos que afetam o mercado do petróleo.
#
# As flutuações nos preços do petróleo podem levar algum tempo para se refletirem nos preços da gasolina, considerando as cadeias de suprimentos, os estoques existentes e os contratos de fornecimento que já estão em vigor. Além disso, eventos específicos, como crises internacionais ou mudanças abruptas na produção de petróleo, podem impactar os preços de maneira mais imediata.
#
# Portanto, concluímos que, embora a análise realizada não tenha encontrado uma correlação clara entre os preços do petróleo e os preços da gasolina em um curto período de tempo, é necessário considerar uma abordagem mais ampla e de longo prazo para compreender melhor as relações complexas entre essas duas variáveis no mercado de combustíveis.

# %% [markdown]
# ## <center> <font color = 'seagreen'> **Considerações Finais** </font> </center>
#
# Nesta análise abrangente dos preços dos combustíveis no Brasil, foram obtidos insights valiosos que lançam luz sobre as dinâmicas desse mercado complexo. Ao longo deste trabalho, destacaram-se várias conclusões importantes:
#
#   **Variação de Preços e Tendências:** Foi observado um comportamento oscilante nos preços dos combustíveis ao longo dos meses de maio e junho de 2023. Embora tenha ocorrido uma queda inicial nos preços em maio, essa tendência foi revertida em junho, possivelmente influenciada pela mudança na cobrança do ICMS pelos Estados.
#
#   **Diferenças Regionais:** Os preços dos combustíveis variam significativamente entre os estados e regiões do Brasil. Os estados da região Norte, como Amazonas e Acre, frequentemente apresentam os preços mais altos, enquanto estados da região Sul, como Santa Catarina, apresentam preços mais baixos.
#
#   **Bandeiras e Preços:** As bandeiras de combustíveis também influenciam nos preços, sendo a bandeira "BRANCA" a mais comum. Embora não tenha sido identificada uma correlação direta entre as bandeiras e os preços, essa análise proporciona uma visão interessante sobre como diferentes bandeiras competem no mercado.
#
#   **Correlações:** Ao investigar a correlação entre preços dos combustíveis, regiões e bandeiras, observou-se que as correlações variam de moderadas a fortes em alguns casos. A relação entre os preços dos combustíveis e a região de venda mostrou uma tendência mais evidente, sugerindo que fatores regionais podem ter um impacto significativo nos preços.
#
#   **Petróleo e Gasolina:** Embora tenha sido realizada uma análise entre os preços do petróleo e os preços da gasolina, o período limitado considerado pode não ser suficiente para identificar uma correlação clara. Ficou evidente a complexidade das relações entre esses dois elementos, destacando a necessidade de uma análise mais abrangente.
#
# Em síntese, essa análise destaca a complexidade do mercado de combustíveis e as múltiplas variáveis que o influenciam. As tendências de preços, diferenças regionais, impacto das bandeiras e correlações entre elementos são áreas-chave que merecem uma análise mais aprofundada em estudos futuros. Além disso, a importância de considerar um período mais longo ao analisar correlações entre o preço do petróleo e o valor da gasolina foi enfatizada.
#
# As conclusões aqui destacadas servem como base para uma compreensão mais abrangente das flutuações dos preços dos combustíveis no Brasil e podem ser úteis para tomadas de decisão no mercado de energia e economia como um todo.
