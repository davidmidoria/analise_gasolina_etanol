# %%
import script as sc

# %%
sc.grafico_combustiveis()

# %%
sc.estados_maior_preco()
# Out:
# ['Acre', 'Rio Grande do Sul', 'Rondônia', 'Roraima', 'Amapá']
# ['Alagoas', 'Roraima', 'Rondônia', 'Acre', 'Amazonas']
# ['Alagoas', 'Roraima', 'Rondônia', 'Acre', 'Amazonas']
