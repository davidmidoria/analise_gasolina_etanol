# %%
import script as sc

# %%
sc.lancamento_dados()

# %%
# Out:
#          Regiao     Estado          Municipio             Produto  \
# 0       Sudeste  São Paulo           SOROCABA              ETANOL
# 1       Sudeste  São Paulo           SOROCABA            GASOLINA
# 2         Norte       Acre  CRUZEIRO\nDO\nSUL              ETANOL
# 3         Norte       Acre  CRUZEIRO\nDO\nSUL  GASOLINA ADITIVADA
# 4         Norte       Acre  CRUZEIRO\nDO\nSUL            GASOLINA
# ...         ...        ...                ...                 ...
# 49036  Nordeste      Bahia           CAMACARI            GASOLINA
# 49037  Nordeste      Bahia           CAMACARI              ETANOL
# 49038  Nordeste      Bahia           CAMACARI  GASOLINA ADITIVADA
# 49039  Nordeste      Bahia           CAMACARI            GASOLINA
# 49040  Nordeste      Bahia           CAMACARI            GASOLINA
#
#       Data da Coleta  Valor de Venda  Bandeira Dia da Semana
# 0         2023-05-01            3.79    BRANCA    01/05/2023
# ...

# %%
sc.panzer()

# %%
sc.grafico_combustiveis()

# %%
print(f'media Gasolina: R$ {sc.media_combustivel[0]:.2f}\nmedia ETANOL: R$ {sc.media_combustivel[1]:.2f}\nmedia GASOLINA ADITIVADA R$ {sc.media_combustivel[2]:.2f}')
# Out:
# media Gasolina: R$ 4.06
# media ETANOL: R$ 5.39
# media GASOLINA ADITIVADA R$ 5.57

# %%
sc.estados_maior_preco()

# %%
sc.media_gasolina()

# %%
sc.media_gasolina_adit()

# %%
sc.media_etanol()

# %%
sc.municipios_baratos()

# %%
sc.municipios_caros()

# %%
sc.grafico_regiao()

# %%
sc.correlacao_combustivel()

# %%
sc.grafico_correlacao('#a51b0b','correlação GASOLINA','GASOLINA')

# %%
sc.grafico_correlacao('#d11507','correlação GASOLINA ADITIVADA','GASOLINA ADITIVADA')

# %%
sc.grafico_correlacao('royalblue','correlação ETANOL','ETANOL')
